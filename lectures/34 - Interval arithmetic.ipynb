# %% [markdown]
# # Rump's example

# %%
3//4
# Out:
# 3//4

# %%
typeof(ans)
# Out:
# Rational{Int64}

# %%
f(a, b) = (333 + 3//4)*b^6 + a^2 * (11*a^2 * b^2 - b^6 - 121b^4 - 2) + 
            (5 + 1//2)*b^8 + (a / (2b))
# Out:
# f (generic function with 1 method)

# %%
a, b = 77617, 33096
# Out:
# (77617, 33096)

# %%
f(a, b)
# Out:
# OverflowError: 1335 * 1196824300446875648 overflowed for type Int64
#
# Stacktrace:
#  [1] throw_overflowerr_binaryop(::Symbol, ::Int64, ::Int64) at ./checked.jl:154
#  [2] checked_mul at ./checked.jl:288 [inlined]
#  [3] * at ./rational.jl:272 [inlined]
#  [4] *(::Rational{Int64}, ::Int64) at ./promotion.jl:312
#  [5] f(::Int64, ::Int64) at ./In[6]:1
#  [6] top-level scope at In[8]:1

# %%
f(Float32(a), Float32(b))
# Out:
# -6.338253f29

# %%
f(Float64(a), Float64(b))
# Out:
# -1.1805916207174113e21

# %%
setprecision(128)
# Out:
# 128

# %%
f(BigFloat(a), BigFloat(b))
# Out:
# -0.8273960599468213681411650954798162919996

# %%
f(big(a), big(b))
# Out:
# -0.8273960599468213681411650954798162919996

# %%
f(big(a)//1, big(b)//1)
# Out:
# -54767//66192

# %%
typeof(big(a))
# Out:
# BigInt

# %%
big(-54767//66192)^20
# Out:
# 58935780610743653480674360515507036680392771136752412282302990646186499977772265029265830561601//2606814157880448652180837055057880008505017382998761770606334741667755860032387968094279854718976

# %%
Float64(-54767//66192)
# Out:
# -0.8273960599468214

# %% [markdown]
# ## Kahan's example

# %%
f(x) = (1/50) * log(abs(3*(1 - x)+1)) + x^2 + 1
# Out:
# f (generic function with 2 methods)

# %%
using Plots

# %%
plot(1:0.00001:2, f)
