# %% [markdown]
# # Rump's example

# %%
f(a, b) = (333 + 3//4)*b^6 + a^2 * (11*a^2 * b^2 - b^6 - 121b^4 - 2) + 
            (5 + 1//2)*b^8 + (a / (2b))
# Out:
# f (generic function with 1 method)

# %%
a, b = 77617, 33096
# Out:
# (77617, 33096)

# %% [markdown]
# ## Kahan's example

# %%
f(x) = (1/50) * log(abs(3*(1 - x)+1)) + x^2 + 1
# Out:
# f (generic function with 2 methods)

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260
#
# signal (11): Segmentation fault: 11
# in expression starting at none:0
# jl_collect_backedges at /Users/julia/buildbot/worker/package_macos64/build/src/dump.c:1253 [inlined]
# jl_save_incremental at /Users/julia/buildbot/worker/package_macos64/build/src/dump.c:2866
# jl_write_compiler_output at /Users/julia/buildbot/worker/package_macos64/build/src/precompile.c:66
# jl_atexit_hook at /Users/julia/buildbot/worker/package_macos64/build/src/init.c:227
# main at /Applications/Julia-1.4.app/Contents/Resources/julia/bin/julia (unknown line)
# Allocations: 138866822 (Pool: 138828511; Big: 38311); GC: 126
# Failed to precompile Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] to /Users/dpsanders/.julia/compiled/v1.4/Plots/ld3vC_Oba5B.ji.
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1272
# ...

# %%
plot(1:0.00001:2, f)
