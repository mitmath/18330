# %%
hs = 0.001:0.001:0.5
# Out:
# 0.001:0.001:0.5

# %%
f(x) = x^3 - 2x^2 + 1

a = 2.0
# Out:
# 2.0

# %%
fp(x) = 3x^2 - 4x
# Out:
# fp (generic function with 1 method)

# %%
fp(a)
# Out:
# 4.0

# %%
g(h) = (f(a + h) - f(a)) / h
# Out:
# g (generic function with 1 method)

# %%
data = [(f(a + h) - f(a)) / h for h in hs];

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
scatter(hs, data)

# %%
# range from 1e-16 to 1e-1 equally spaced on a log axis

# %%
hs = [10.0^(i) for i in -16:0.01:-1];

# %%
scatter(hs, g.(hs))

# %%
δs = g.(hs) .- 4;

# %%
scatter(hs, abs.(δs), scale=:log10)
plot!(x -> x)

# %%
δs
# Out:
# 1501-element Array{Float64,1}:
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#  -4.0
#   ⋮
#   0.31652444251222
#   0.32404086733451276
#   0.3317391409457091
#   0.33962381815024667
#   0.34769957488169734
#   0.35597121173273294
#   0.3644436576007486
#   0.3731219734533733
#   0.38201135621834936
#   0.39111714280212784
#   0.40044481424252165
#   0.41000000000000725

# %%
g2(h) = (f(a + h) - f(a - h)) / (2h)
# Out:
# g2 (generic function with 1 method)

# %%
δ2s = g2.(hs) .- 4;

scatter(hs, abs.(δs), scale=:log10, alpha=0.5, label="forward")
scatter!(hs, abs.(δ2s), scale=:log10, alpha=0.5, label="centered")

plot!(h -> h, ls=:dash)
plot!(h -> h^2, ls=:dash, leg=:bottomright)
