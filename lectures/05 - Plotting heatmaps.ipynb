# %%
using Plots

# %%
M = rand(10, 10)
# Out:
# 10×10 Array{Float64,2}:
#  0.549824    0.343497  0.473467  0.590348  …  0.895754  0.0575716  0.791457
#  0.176888    0.689344  0.956868  0.796094     0.716873  0.268841   0.563141
#  0.678745    0.987011  0.373178  0.679215     0.710879  0.789169   0.552277
#  0.119594    0.260582  0.452707  0.258404     0.975375  0.202344   0.461213
#  0.805489    0.949309  0.534636  0.0663       0.61614   0.402169   0.327773
#  0.310876    0.670344  0.79086   0.289189  …  0.947146  0.938295   0.921718
#  0.00329933  0.275298  0.298124  0.596835     0.752293  0.0732672  0.777325
#  0.597855    0.464973  0.691958  0.441569     0.151734  0.0827455  0.613005
#  0.320971    0.707493  0.793164  0.371112     0.249883  0.665685   0.241311
#  0.339062    0.676376  0.991247  0.895485     0.325564  0.609589   0.810463

# %%
heatmap(M, ratio=1)

# %%
heatmap(range(-1, 1, length=10), range(-1, 1, length=10), M, ratio=1)

# %%
surface(M)

# %%
]add PlotlyJS ORCA
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Fetching: [===================>                     ]
#     Fetching: [======================================
#     Fetching: [========================================>]  100.0 %
#   Resolving package versions...
#   Installed PlotlyJS ─ v0.13.1
#    Updating `~/.julia/environments/v1.4/Project.toml`
#   [47be7bcc] + ORCA v0.3.1
#   [f0f68f2c] + PlotlyJS v0.13.1
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#   [9e28174c] + BinDeps v1.0.0
#   [ad839575] + Blink v0.12.1
#   [9fb69e20] + Hiccup v0.2.2
#   [50d2b5c4] + Lazy v0.14.0
#   [ffc61752] + Mustache v1.0.0
#   [a975b10e] + Mux v0.7.1
#   [47be7bcc] + ORCA v0.3.1
#   [a03496cd] + PlotlyBase v0.3.0
#   [f0f68f2c] + PlotlyJS v0.13.1
#   [30578b45] + URIParser v0.4.0
#   [0c0b7dd1] ↑ Xorg_libXau_jll v1.0.9+0 ⇒ v1.0.9+1
#   [935fb764] ↑ Xorg_libXcursor_jll v1.2.0+0 ⇒ v1.2.0+1
# ...

# %%
plotlyjs()
# Out:
# ┌ Info: Precompiling PlotlyJS [f0f68f2c-4968-5e81-91da-67840de0976a]
# └ @ Base loading.jl:1260
# ...
